# %% [markdown]
# Project 1: Exploratory Data Analysis- Gapminder dataset
#
# The Gapminder dataset provides population data from 1952 to 2007 (at 5 year intervals) for several countries around the world. Compare the populations of the European countries France, United Kingdom, Italy, Germany and Spain over this period using a line chart. Make appropriate modifications to the chart title, axis titles, legend, figure size, font size, colors etc. to make the chart readable and visually appealing. # Line Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv(r"C:\Users\Kshama\OneDrive\Desktop\notes\Week1\datasets\gapminderDataFiveYears.csv")

# Select European countries
countries = ["France", "United Kingdom", "Italy", "Germany", "Spain"]
data = df[df["country"].isin(countries)]

# Create line chart
plt.figure(figsize=(12, 7))

for c in countries:
    country_data = data[data["country"] == c]
    plt.plot(country_data["year"], country_data["pop"], marker='o', linewidth=2, label=c)

# Chart formatting
plt.title("Population Comparison of European Countries (1952–2007)", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Population", fontsize=12)
plt.legend(title="Country", fontsize=11)
plt.grid(True, linestyle='--', alpha=0.6)

# Display chart
plt.tight_layout()
plt.show()

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Kshama\OneDrive\Desktop\notes\Week1\datasets\gapminderDataFiveYears.csv")

# Display top 5 rows
print(df.head())
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# Project 2: Exploratory Data Analysis -Diamonds dataset
#
# diamonds_url points to a CSV file containing varnous attrbutes like carat, cut, color, clarly, prlce etc, for over 53, 000 dlamonds, Visualize the relationship between, the carat (size of diamond)and price using a scatter plot Instead of using the enlire dataset for this visuallzatlon, just plck the dlamonds wilth a clarily "SI2" and color "E", Use the values of the "'caut' column to color th dols in the scatter plot Make appropriate modiications to the chart title, axls ttleos, legend, igure slze, font slze, colors ete, to make the chart readable and visually appealing # Scatterplot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Dataset load karo
df = pd.read_csv(r"C:\Users\Kshama\OneDrive\Desktop\notes\Week1\datasets\diamonds.csv")

# Step 2: Sirf SI2 clarity aur E color ka data filter karo
filtered_data = df[(df["clarity"] == "SI2") & (df["color"] == "E")]

# ---------------- Bar Chart ----------------
avg_price_by_cut = filtered_data.groupby("cut")["price"].mean()

plt.figure(figsize=(10, 6))
plt.bar(avg_price_by_cut.index, avg_price_by_cut.values)
plt.title("Average Price by Cut (Bar Chart)")
plt.xlabel("Cut")
plt.ylabel("Average Price")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# ---------------- Pie Chart ----------------
cut_counts = filtered_data["cut"].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(cut_counts, labels=cut_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Cut Distribution (Pie Chart)")
plt.show()

# %% [markdown]
# Project 3: Exploratory Data Analysis - Planets dataset
#
#
# The Planets dataset contains details about the 1,000+ extrasolar planets discovered up to 2014. Visualize the distribution of the masses of the planets (expressed as a multiple of the mass of Jupiter), using a histogram and a box plot. Make appropriate modifications to the chart title, axis titles, legend, figure size, font size, colors etc. to make the chart readable and visually appealing. - Histogram and Box Plot # type: ignore

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Load dataset
df = pd.read_csv(r"C:\Users\Kshama\OneDrive\Desktop\notes\Week1\datasets\planets.csv")

# Step 2: Sirf mass column lo aur missing values hatao
mass_data = df["mass"].dropna()

# ---------------- Histogram ----------------
plt.figure(figsize=(10, 6))
plt.hist(mass_data, bins=30, edgecolor='black')
plt.title("Distribution of Planet Masses (in Jupiter Masses)", fontsize=14)
plt.xlabel("Planet Mass (Jupiter Mass)", fontsize=12)
plt.ylabel("Number of Planets", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()


# ---------------- Box Plot ----------------
plt.figure(figsize=(8, 5))
plt.boxplot(mass_data, vert=False)
plt.title("Box Plot of Planet Masses (in Jupiter Masses)", fontsize=14)
plt.xlabel("Planet Mass (Jupiter Mass)", fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
